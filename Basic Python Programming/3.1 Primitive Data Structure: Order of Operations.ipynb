# %% [markdown]
# <a href="https://colab.research.google.com/github/suryoadi12/PACMANN_SKILLS100/blob/main/Basic%20Python%20Programming/3.1%20Primitive%20Data%20Structure%3A%20Order%20of%20Operations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Pertemuan #2-2 - Order of Operations (PEMDAS)**

# %% [markdown]
# **2. ORDER OF OPERATIONS (PEMDAS)**

# %% [markdown]
# Setiap operasi matematika memiliki **urutan dalam penyelesaiannya**. Jika dalam satu ekspresi terdapat lebih dari satu operasi, maka harus di selesaikan berdasarkan operasi yang lebih tinggi prioritasnya. Untuk lebih mudah mengingat aturan ini bisa menggunakan akronim **PEMDAS**:

# %% [markdown]
# ![alsjdfl.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# **PARENTHESES (TANDA KURUNG)**

# %% [markdown]
# Tanda kurung memiliki **prioritas tertinggi** dan dapat digunakan untuk memaksa ekspresi dievaluasi dalam urutan yang dinginkan.
#
# Karena ekspresi dalam tanda kurung dievaluasi terlebih dahulu, maka `2 * (3-1)` adalah `4`, dan `(1+1)**(5-2)` adalah `8`.

# %%
# Coba jalankan code dibawah ini

print(2*(3-1))
# Out:
# 4

# %%
# Coba berikan tanda kurung buka dan kurung tutup diantara bilangan tiga dan satu

print(6*(3-1))
# Out:
# 12

# %%
# Coba berikan variabel pada bilangan 1, 5 dan 2
# Kemudian lengkapi code dan masukkan variabel
# Kedalam titik-titik dibawah sesuai dengan operasi (1+1)**(5-2)
# Jangan lupa terapkan penggunaan "good" variables!

num_1 = 1
num_2 = 5
num_3 = 2
print((num_1+num_1)**(num_2-num_3))
# Out:
# 8

# %% [markdown]
# **EXPONENTS (PANGKAT)**

# %% [markdown]
# Pangkat memiliki prioritas tertinggi berikutnya, jadi `2**1+1` adalah `3`, bukan `4`, dan `3*1**3` adalah `3`, bukan `27`.

# %%
# Coba jalankan code dibawah ini

print(2**1+1)
# Out:
# 3

# %%
# Coba isi titik-titik berikut dengan operasi pangkat di python

print(3**1+1)
# Out:
# 4

# %%
# Coba ketik kembali dengan ekspresi matematika pada titik-titik dibawah
# Empat dikali dua pangkat tiga

print(4*2**3)
# Out:
# 32

# %%
# Coba berikan variabel pada bilangan 4, 2 dan 3
# Kemudian hitung variabel sesuai dengan operasi 4*2**3

angka_1 = 4
angka_2 = 2
angka_3 = 3
print(angka_1*angka_2**angka_3)
# Out:
# 32

# %% [markdown]
# **MULTIPLICATION AND DIVISION**

# %% [markdown]
# Prioritas selanjutnya adalah perkalian dan pembagian.
#
# Perkalian dan pembagian memiliki prioritas yang sama, dan **lebih tinggi dari penjumlahan dan pengurangan**.
#
# Jadi `2*3-1` adalah `5`, bukan `4`,
#
# dan
#
# `6+4/2` adalah `8`, bukan `5`.

# %%
# Coba jalankan code dibawah ini

print(2*3-1)
# Out:
# 5

# %%
# Coba lengkapi titik-titik dibawah dengan tanda perkalian

print(6*3-1)
# Out:
# 17

# %%
# Coba lengkapi titik-titik dibawah dengan tanda pembagian

print(10+4/2)
# Out:
# 12.0

# %%
# Coba berikan variabel pada masing-masing bilangan 10, 4 dan 2
# Kemudian hitung dengan variabel dengan operasi 10 + 4 / 2

num_1 = 10
num_2 = 4
num_3 = 2
print(num_1+num_2/num_3)
# Out:
# 12.0

# %% [markdown]
# **ADDITION AND SUBTRACTION**

# %% [markdown]
# Penambahan dan Pengurangan memiliki **prioritas paling rendah** dibandingkan dengan operator yang lain.

# %%
# Coba lengkapi titik-titik dibawah dengan tanda penambahan

print(4+5+6)
# Out:
# 15

# %%
# Buatlah variabel untuk menampung setiap angka 4, 5 dan 6
# Kemudian lengkapi code dan hitung dengan variabel yang sudah dibuat

angka_1 = 4
angka_2 = 5
angka_3 = 6
print(angka_1+angka_2+angka_3)
# Out:
# 15

# %%
# Coba lengkapi titik-titik dibawah dengan tanda pengurangan

print(10-5-1)
# Out:
# 4

# %%
# Buatlah variabel untuk menampung setiap angka yang ada pada soal diatas
# Kemudian hitung dengan variabel yang sudah dibuat

sub_1 = 10
sub_2 = 5
sub_3 = 1
print(sub_1-sub_2-sub_3)
# Out:
# 4

# %% [markdown]
# Jika ada operasi yang memiliki **prioritas yang sama** maka evaluasi dilakukan dari kiri ke kanan.

# %%
# Coba lengkapi titik-titik dibawah dengan tanda perkalian

print(4*7/8*3)
# Out:
# 10.5

# %%
# Coba hitung operasi 6*12/4 dengan variabel dibawah

rank_1 = 6
rank_2 = 12
rank_3 = 4
print(rank_1*rank_2/rank_3)
# Out:
# 18.0

# %% [markdown]
# **EXERCISE**

# %% [markdown]
# 1. Pak Bambang menabung dibank sebesar Rp 10.000.000. Jika persentase bunga per tahun sebesar 5%, berapa besar bunga yang diterima Pak Bambang setelah 5 tahun menabung?
#
# `hint: Besar_bunga = Lama_menabung x persentase_bunga x besar_tabungan`

# %%
# Declare variabel yang akan dihitung
besar_tabungan = 10_000_000
persentase_bunga = 0.05
lama_menabung = 5

# Hitung besar bunga yang didapat setelah 5 tahun menabung
besar_bunga = lama_menabung*persentase_bunga*besar_tabungan

print(besar_bunga)
# Out:
# 2500000.0

# %% [markdown]
# 2. Ibu Mega sedang berbelanja ke toko buah untuk acara arisan. Beliau membeli buah Jeruk sebanyak 1 kg, buah Rambutan 2 kg, Semangka 2 buah yang beratnya masing-masing 4.2 kg dan 4.5 kg. Jika harga Jeruk Rp 22000 per kg, Rambutan Rp 20000 per kg, Semangka Rp 4000 per kg. Ternyata toko memberikan diskon sebesar 20% dari harga total pembelian. Berapakah total harga belanjaan Ibu Mega?

# %%
# Hitung harga buah yang dibeli
harga_jeruk = 1*22000
harga_rambutan = 2*20000
harga_semangka = 40000*(4.2+4.5)

# Hitung total harga buah sebelum diskon
harga_sebelum_diskon = harga_jeruk+harga_rambutan+harga_semangka

# Hitung diskon yang diterima dari total harga semua buah
diskon = harga_sebelum_diskon*0.2

# Hitung harga yang didapat setelah mendapatkan diskon
harga_setelah_diskon = harga_sebelum_diskon-diskon

print(harga_sebelum_diskon)
print(harga_setelah_diskon)
print(diskon)
# Out:
# 410000.0
# 328000.0
# 82000.0
