# %% [markdown]
# <a href="https://colab.research.google.com/github/suryoadi12/PACMANN_SKILLS100/blob/main/Basic%20Python%20Programming/6.%20Composite%20Data%20Structure%3A%20Introduction%20to%20Composite%20Data%20Structure.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **COMPOSITE DATA STRUCTURE**

# %% [markdown]
# 1. **COMPOSITE DATA STRUCTURE ON PYTHON**

# %% [markdown]
# Sebelumnya kita telah mengenal tipe data pada angka dan string atau karakter, yang merupakan tipe data yang paling umum.
#
#
#
# *   Primitive Data Structure adalah unit dasar bahasa pemrograman apapun.
#
# *   Setiap nilai primitif berisi satu tipe data. Contohnya:
#
#     *   Judul film
#     *   Nama orang
#     *   Tinggi badan
#     *   dsb.
#
#
# *   Namun tipe data primitif tidak bisa mengakomodasi tingkat kerumitan yang lebih tinggi, misalnya menyimpan daftar nama siswa di Sekolah, jika hanya ada tiga sampai lima siswa saja di suatu sekolah masih bisa di simpan dengan mendefinisikan variabel untuk menyimpan data.

# %%
# Siswa di suatu sekolah

siswa_1 = "Budi"
siswa_2 = "Anto"
siswa_3 = "Wahyu"
siswa_4 = "James"
siswa_5 = "Adam"

# %% [markdown]
# *   Tapi, jika ada seratus atau bahkan seribu data apakah akan membuat seribu variabel? Hal itu mungkin saja dilakukan namun tidak efisien, kita butuh suatu yang lain.

# %% [markdown]
# Contoh lain:
#
#
#
# *   Semisal dalam melakukan pengolahan data di Python, data yang ingin diolah itu bukan hanya 1, tetapi bisa banyak.
#
# *   Ketika menggunakan Excel kita bisa menyimpan ribuan data dan memanggilnya dengan mudah.
# *   Bagimana kalau di Python? Bagaimana cara kita menyimpan dan mengolah data yang banyak?
#
#
# Untuk penanganan data yang lebih rumit atau kompleks seperti kasus di atas kita bisa menggunakan **Composite Data Structure**.

# %% [markdown]
# **WHAT IS COMPOSITE DATA STRUCTURE?**

# %% [markdown]
# Composite Data Structure adalah tipe data yang tersusun (composed) dari dua atau lebih tipe data primitif (`int, float, string, boolean`).

# %% [markdown]
# **Composite Data Structure vs Primitive Data Structure**

# %% [markdown]
# Perbedaan Composite Data Structure dan Primitive Data Structure bisa dilihat pada tabel dibawah:

# %% [markdown]
# ![asdlfas.JPG](data:image/jpeg;base64,...)
