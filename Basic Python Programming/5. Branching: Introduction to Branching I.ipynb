# %% [markdown]
# <a href="https://colab.research.google.com/github/suryoadi12/PACMANN_SKILLS100/blob/main/Basic%20Python%20Programming/5.%20Branching%3A%20Introduction%20to%20Branching%20I.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Apa itu Branching?** 🤔

# %% [markdown]
# *   **Branching** atau percabangan adalah salah satu bentuk kontrol pada suatu program.
#
# *   Percabangan berguna untuk **mengatur** jalannya program sesuai dengan suatu kondisi yang terpenuhi.
# *   Percabangan juga mampu membuat sebuah program menentukan suatu tindakan sesuai dengan logika/kondisi yang diberikan.
#
#
# *   Dalam pemrograman Python, terdapat tiga keywords untuk melakukan percabangan, yaitu `if`, `elif`, dan `else`.

# %% [markdown]
# *   Jika saya diterima bekerja di Perusahaan A, saya akan menduduki jabatan Data Scientist.
#
# *   Jika tidak diterima saya akan apply di perusahaan B untuk jabatan Data Analyst.
# *   Jika masih tidak lolos, maka saya akan membuka usaha cafe.
#
#
# Ilustrasi nya sebagai berikut:

# %% [markdown]
# ![lasdjfoewf.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# **SYNTAX BRANCHING**

# %% [markdown]
# Berikut merupakan syntax dari statement `if`, `elif`, dan `else`:

# %% [markdown]
# ![dsafdsfs.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# *   **Condition** memiliki nilai **True** atau **False**.
# *   Mengevaluasi ekspresi di blok tersebut jika condition True.

# %% [markdown]
# **INDENTATION**

# %% [markdown]
# *   Secara praktis kita bisa menggunakan tombol tab untuk memberikan **indentation**.
#
# *   Kegunaan dari indentation akan lebih terasa saat kita melakukan **branching**, dan juga saat looping atau membuat fungsi.
# *   Indentation merupakan bagian dari syntax python.

# %% [markdown]
# Contoh:

# %%
print("Ayam goreng enak")
# Out:
# Ayam goreng enak

# %% [markdown]
# Namun, kita tidak bisa melakukan hal seperti di bawah ini:

# %%
makanan = "Ayam goreng"
          print(makanan)
# Out:
#   File "<ipython-input-2-4f2fda6dd6cb>", line 2
#     print(makanan)
#     ^
# IndentationError: unexpected indent

# %%
                        makanan = "Ayam goreng"
    print(makanan)
# Out:
#   File "<ipython-input-3-81a581942106>", line 2
#     print(makanan)
#     ^
# IndentationError: unexpected indent

# %% [markdown]
# Yang bisa kita lakukan adalah seperti ini:

# %%
                                makanan = "Ayam goreng"
                                print(makanan)
# Out:
# Ayam goreng

# %% [markdown]
# Perbedaan spasi antar baris hanya bisa dilakukan jika kita melakukan **conditional, loop, fungsi, dan class**. Jika bukan, maka antar baris haruslah **sejajar**.

# %% [markdown]
# **BASIC IF**

# %% [markdown]
# ![lsdjfowef.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# *   Percabangan If digunakan saat terdapat pada satu kondisi.
# *   Pada percabangan If, kita menggunakan **Operator Equality atau Comparison** pada condition.

# %% [markdown]
# Bayangkan jika kamu akan pergi ke Pantai jika cuaca cerah, dan cuaca saat ini cerah.
#
# Maka ilustrasinya akan sebagai berikut:

# %% [markdown]
# ![asldjfew;fsd.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# Kondisi di atas jika dituliskan pada pernyataan `if` akan sebagai berikut:

# %%
# Declare variabel kondisi cuaca
kondisi_cuaca = "Cerah"

# If jika kondisi cuaca cerah
if kondisi_cuaca == "Cerah":
  # Statement jika memenuhi if kondisi jika cuaca cerah
  print("Aku pergi ke pantai")
# Out:
# Aku pergi ke pantai

# %% [markdown]
# **Contoh lain**: Supermarket A memberikan harga diskon 15% kepada pelanggan yang bertransaksi belanja lebih dari Rp100.000. Wawan tertarik dengan promosi tersebut maka Wawan membeli kebutuhan Wawan dan ternyata didapatkan hasil:
#
# Kondisi di atas dapat di dituliskan ke dalam pernyataan `if`, seperti berikut:

# %%
total_belanja_wawan = 110_000
min_belanja = 100_000

# If kondisi jika total belanja wawan lebih besar sama dengan min. belanja
if total_belanja_wawan >= 100_000:
  # Statement yang dikeluarkan jika memenuhi kondisi If diatas
  print("Selamat, anda mendapatkan diskon 15%")

# Menghitung total akhir belanja setelah diskon
total_akhir = total_belanja_wawan-(total_belanja_wawan*0.15)
print("Total akhir belanja anda sebesar", total_akhir)
# Out:
# Selamat, anda mendapatkan diskon 15%
# Total akhir belanja anda sebesar 93500.0

# %% [markdown]
# Ternyata total belanja Wawan melebihi syarat ketentuan diskon, maka dia berhak mendapatkan diskon.

# %% [markdown]
# Selain menggunakan tipe data text atau angka, kita juga bisa melakukan branching dengan tipe data boolean!
#
#
#
# *   Semisal, Tono ingin mengecek apakah produk Ayam Geprek nya bisa mendapatkan promo atau tidak. Maka, dia membuat branching seperti di bawah ini:

# %%
# Declare variabel apakah bisa mendapatkan promo
is_promo = True

# If bisa mendapatkan promo
if is_promo == True:
  # Statement yang dikeluarkan jika memenuhi kondisi If diatas
  print("Selamat, anda mendapatkan promo")
# Out:
# Selamat, anda mendapatkan promo

# %% [markdown]
# **MINI EXERCISE**

# %% [markdown]
# Seorang murid mendapatkan nilai 80, buatlah if condition, jika nilai lebih dari sama dengan 70 akan mengeluarkan output "**lulus**".

# %%
# Declare variabel nilai murid
nilai_murid = 80

# If nilai murid lebih dari sama dengan 70
if nilai_murid >= 70:
  # Statement yang dikeluarkan jika memenuhi kondisi If diatas
  print("Lulus")
# Out:
# Lulus

# %% [markdown]
# **BASIC IF/ELSE**

# %% [markdown]
# **if/else** diperlukan ketika branching memiliki 2 kondisi:

# %% [markdown]
# ![aldjfoefasl.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# Misalkan, kamu pergi ke Pantai jika cuaca cerah, namun hari ini hujan maka kamu pergi ke Bioskop.
#
# Maka ilustrasinya seperti berikut:

# %% [markdown]
# ![uaosof.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# Maka, jika ditulis bentuk pernyataan **if/else** menjadi:

# %%
kondisi_cuaca = "Hujan"

# If kondisi jika cuaca sama dengan cerah
if kondisi_cuaca == "Cerah":
  # Statement yang dikeluarkan jika memenuhi kondisi If diatas
  print("Aku pergi ke pantai")
# Jika tidak memenuhi kondisi If diatas
else:
  print("Aku pergi ke bioskop")
# Out:
# Aku pergi ke bioskop

# %% [markdown]
# Contoh lain: Wawan ingin membeli laptop seharga 20.000.000. Namun, uang yang dimiliki Wawan sebanyak 15.000.000.

# %%
harga_laptop = 20_000_000
uang_wawan = 15_000_000

# If uang wawan lebih dari sama dengan harga laptop
if uang_wawan >= harga_laptop:
  # Statement yang dikeluarkan jika memenuhi kondisi If diatas
  print("Wawan dapat membeli laptop")
# Jika tidak memenuhi kondisi If diatas
else:
  print("Wawan harus menabung lagi")

# %% [markdown]
# **MINI EXERCISE**

# %% [markdown]
# Lengkapi program dibawah ini menentukan nilai genap dan ganjil dengan menggunakan modulus, buatlah satu kondisi sehingga mengeluarkan nilai ganjil.

# %%
angka = 2

if angka & 2 == 0:
  print("Nilai genap")
else:
  print("Nilai ganjil")
# Out:
# Nilai ganjil

# %% [markdown]
# Dalam hal ini, penggunaan spasi sangatlah penting untuk membedakan antara perintah **if/else** dengan pernyataan setelahnya.
#
# Bagaimana jika kita tidak menggunakan spasi untuk pernyataan **if/else** sebelumnya? Mari cek.

# %%
if uang_wawan >= harga_laptop:
print("mendapatkan diskon 15%")
else:
print("tidak mendapatkan diskon")
# Out:
#   File "<ipython-input-18-9f8eb7816128>", line 2
#     print("mendapatkan diskon 15%")
#     ^
# IndentationError: expected an indented block after 'if' statement on line 1

# %% [markdown]
# Maka penting untuk kita menggunakan spasi. Ada juga yang senang menggunakan `tab`, namun itu semua kembali ke preferensi masing - masing.

# %%
# Menggunakan spasi 1 kali
if uang_wawan >= harga_laptop:
print("mendapatkan diskon 15%")
else:
 print("tidak mendapatkan diskon"
# Out:
#   File "<ipython-input-19-76a33de68c37>", line 3
#     print("mendapatkan diskon 15%")
#     ^
# IndentationError: expected an indented block after 'if' statement on line 2

# %%
# Menggunakan spasi yang berbeda untuk tiap statement
if uang_wawan >= harga_laptop:
                  print("mendapatkan diskon 15%")
else:
 print("tidak mendapatkan diskon"
# Out:
#   File "<ipython-input-20-b2800675f0b4>", line 5
#     print("tidak mendapatkan diskon"
#                                     ^
# SyntaxError: incomplete input
